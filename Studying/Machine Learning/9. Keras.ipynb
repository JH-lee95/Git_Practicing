# %% [markdown]
# ## 폐암환자 케라스

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation

# %%
np.random.seed(0)
tf.random.set_seed(0)

# %%
Data_set=np.loadtxt("ThoraricSurgery.csv",delimiter=",")

# %%
# Data_set,Data_set.shape

# %%
X=Data_set[:,:-1]
Y=Data_set[:,[-1]]

# %%
model=Sequential()
model.add(Dense(30,input_dim=17,activation='relu')) #input_dim을 명시함으로써 입력층과 은닉층을 겸함
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer="Adam",loss="mean_squared_error",metrics=['accuracy'])
model.fit(X,Y,epochs=30,batch_size=10)
# Out:
# Train on 470 samples
# Epoch 1/30
# 470/470 [==============================] - 0s 490us/sample - loss: 0.3998 - accuracy: 0.5745
# Epoch 2/30
# 470/470 [==============================] - 0s 80us/sample - loss: 0.1493 - accuracy: 0.8511
# Epoch 3/30
# 470/470 [==============================] - 0s 86us/sample - loss: 0.1488 - accuracy: 0.8511
# Epoch 4/30
# 470/470 [==============================] - 0s 88us/sample - loss: 0.1488 - accuracy: 0.8511
# Epoch 5/30
# 470/470 [==============================] - 0s 87us/sample - loss: 0.1488 - accuracy: 0.8511
# Epoch 6/30
# 470/470 [==============================] - 0s 90us/sample - loss: 0.1488 - accuracy: 0.8511
# Epoch 7/30
# 470/470 [==============================] - 0s 90us/sample - loss: 0.1487 - accuracy: 0.8511
# Epoch 8/30
# 470/470 [==============================] - 0s 91us/sample - loss: 0.1486 - accuracy: 0.8511
# Epoch 9/30
# 470/470 [==============================] - 0s 88us/sample - loss: 0.1482 - accuracy: 0.8511
# ...

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_20 (Dense)             (None, 30)                540
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 31
# ...
# Total params: 571
# Trainable params: 571
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("\n Accuracy: %.4f" % (model.evaluate(X,Y)[1]))
# Out:
# 470/470 [==============================] - 0s 125us/sample - loss: 0.1489 - accuracy: 0.8511
#
#  Accuracy: 0.8511

# %% [markdown]
# ## XOR문제 케라스

# %%
training_data=np.array([[0,0],[0,1],[1,0],[1,1]],"float32")
target_data=np.array([[0],[1],[1],[0]],"float32")

model=Sequential()
model.add(Dense(32,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['binary_accuracy'])
model.fit(training_data,target_data,epochs=1000,verbose=2)

print(model.predict(training_data))
print("\n Accuracy: %.4f" %(model.evaluate(training_data,taget_data)[1]))
# Out:
# Train on 4 samples
# Epoch 1/1000
# 4/4 - 0s - loss: 0.7217 - binary_accuracy: 0.2500
# Epoch 2/1000
# 4/4 - 0s - loss: 0.7208 - binary_accuracy: 0.0000e+00
# Epoch 3/1000
# 4/4 - 0s - loss: 0.7198 - binary_accuracy: 0.0000e+00
# Epoch 4/1000
# 4/4 - 0s - loss: 0.7189 - binary_accuracy: 0.2500
# Epoch 5/1000
# 4/4 - 0s - loss: 0.7180 - binary_accuracy: 0.2500
# Epoch 6/1000
# 4/4 - 0s - loss: 0.7171 - binary_accuracy: 0.2500
# Epoch 7/1000
# 4/4 - 0s - loss: 0.7161 - binary_accuracy: 0.2500
# Epoch 8/1000
# 4/4 - 0s - loss: 0.7152 - binary_accuracy: 0.2500
# Epoch 9/1000
# 4/4 - 0s - loss: 0.7143 - binary_accuracy: 0.2500
# Epoch 10/1000
# 4/4 - 0s - loss: 0.7134 - binary_accuracy: 0.2500
# Epoch 11/1000
# 4/4 - 0s - loss: 0.7125 - binary_accuracy: 0.2500
# Epoch 12/1000
# 4/4 - 0s - loss: 0.7117 - binary_accuracy: 0.2500
# Epoch 13/1000
# 4/4 - 0s - loss: 0.7109 - binary_accuracy: 0.2500
# Epoch 14/1000
# 4/4 - 0s - loss: 0.7102 - binary_accuracy: 0.2500
# Epoch 15/1000
# ...

# %% [markdown]
# ## 당뇨문제 케라스

# %%
diabetes=np.loadtxt("data-03-diabetes.csv",delimiter=",")
diabetes
# Out:
# array([[-0.294118 ,  0.487437 ,  0.180328 , ..., -0.53117  , -0.0333333,
#          0.       ],
#        [-0.882353 , -0.145729 ,  0.0819672, ..., -0.766866 , -0.666667 ,
#          1.       ],
#        [-0.0588235,  0.839196 ,  0.0491803, ..., -0.492741 , -0.633333 ,
#          0.       ],
#        ...,
#        [-0.411765 ,  0.21608  ,  0.180328 , ..., -0.857387 , -0.7      ,
#          1.       ],
#        [-0.882353 ,  0.266332 , -0.0163934, ..., -0.768574 , -0.133333 ,
#          0.       ],
#        [-0.882353 , -0.0653266,  0.147541 , ..., -0.797609 , -0.933333 ,
#          1.       ]])

# %%
diabetes.shape
# Out:
# (759, 9)

# %%
x_train=diabetes[:,:-1]
y_train=diabetes[:,[-1]]

# %%
x_train.shape,y_train.shape
# Out:
# ((759, 8), (759, 1))

# %%
model=Sequential()
model.add(Dense(30,input_dim=8,activation='relu'))
model.add(Dense(30,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(loss="mse",optimizer="Adam",metrics=["binary_accuracy"])
model.fit(x_train,y_train,epochs=1000,batch_size=150)
# Out:
# Train on 759 samples
# Epoch 1/1000
# 759/759 [==============================] - 0s 407us/sample - loss: 0.2475 - binary_accuracy: 0.6522
# Epoch 2/1000
# 759/759 [==============================] - 0s 10us/sample - loss: 0.2444 - binary_accuracy: 0.6930
# Epoch 3/1000
# 759/759 [==============================] - 0s 11us/sample - loss: 0.2408 - binary_accuracy: 0.7233
# Epoch 4/1000
# 759/759 [==============================] - 0s 11us/sample - loss: 0.2366 - binary_accuracy: 0.7391
# Epoch 5/1000
# 759/759 [==============================] - 0s 10us/sample - loss: 0.2317 - binary_accuracy: 0.7220
# Epoch 6/1000
# 759/759 [==============================] - 0s 9us/sample - loss: 0.2260 - binary_accuracy: 0.7154
# Epoch 7/1000
# 759/759 [==============================] - 0s 11us/sample - loss: 0.2188 - binary_accuracy: 0.7431
# Epoch 8/1000
# 759/759 [==============================] - 0s 9us/sample - loss: 0.2107 - binary_accuracy: 0.7497
# Epoch 9/1000
# ...

# %%
print(model.predict(x_train))
print("\n Accuracy: %.4f" %(model.evaluate(x_train,y_train)[1]))
# Out:
# [[1.91743784e-02]
#  [9.99667168e-01]
#  [2.04471406e-02]
#  [9.99956131e-01]
#  [3.56387427e-05]
#  [9.72274661e-01]
#  [9.99658704e-01]
#  [9.60818768e-01]
#  [5.78885941e-12]
#  [7.78541155e-03]
#  [9.90667880e-01]
#  [3.38373147e-02]
#  [9.99325037e-01]
#  [2.29693724e-05]
#  [9.91464779e-03]
#  [1.22639753e-01]
#  [3.88703449e-03]
#  [9.95205522e-01]
#  [6.48445860e-02]
#  [3.39716196e-01]
#  [9.11547482e-01]
#  [6.12582062e-06]
#  [1.49959624e-01]
#  [6.28117621e-01]
#  [1.04143459e-03]
#  [9.99856591e-01]
#  [9.73070562e-01]
#  [9.78079021e-01]
#  [9.65608180e-01]
#  [4.48776688e-03]
#  [9.99783218e-01]
#  [9.99889851e-01]
#  [9.37345147e-01]
#  [9.97780025e-01]
#  [9.71163034e-01]
#  [3.53755429e-02]
#  [9.98395026e-01]
#  [6.59054965e-02]
#  [9.90159810e-01]
#  [4.57518250e-01]
#  [9.62258279e-01]
#  [1.27401904e-06]
#  [9.57047462e-01]
#  [6.87443435e-06]
#  [9.61352050e-01]
#  [9.97462869e-01]
#  [1.76486865e-01]
#  [9.12942827e-01]
#  [9.99966025e-01]
#  [9.99842644e-01]
# ...
